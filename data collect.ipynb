# %% [markdown]
# **Data Collection and transformaiton for training the LLM model**

# %%
pip install datasets
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 491.4/491.4 kB 4.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 6.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.6/193.6 kB 11.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.5/143.5 kB 7.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.8/194.8 kB 10.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2025.3.2
#     Uninstalling fsspec-2025.3.2:
#       Successfully uninstalled fsspec-2025.3.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2025.3.2 requires fsspec==2025.3.2, but you have fsspec 2025.3.0 which is incompatible.
# ...

# %%
# data from Github

# %%
from datasets import load_dataset

# Load the 'counsel-chat' dataset
dataset = load_dataset("nbertagnolli/counsel-chat")

# Check the structure of the dataset
print(dataset)
# Out:
# Repo card metadata block was not found. Setting CardData to empty.
# WARNING:huggingface_hub.repocard:Repo card metadata block was not found. Setting CardData to empty.
# DatasetDict({
#     train: Dataset({
#         features: ['questionID', 'questionTitle', 'questionText', 'questionLink', 'topic', 'therapistInfo', 'therapistURL', 'answerText', 'upvotes', 'views'],
#         num_rows: 2775
#     })
# })

# %%
import pandas as pd

# Convert the dataset into a pandas DataFrame
df = dataset['train'].to_pandas()

# Save it as a CSV file
df.to_csv('counsel_chat_data.csv', index=False)

# %%
# Accessing training data
train_data = dataset['train']

type(train_data)
# Out:
# datasets.arrow_dataset.Dataset

# %%
# downloded the data to local system and uploaded to colab file again to keep permenet data as csv

# %%
# getting the data
import pandas as pd

# %%
# Data from Kaggel combining with git data

# Load Hugging Face dataset (converted into a DataFrame)
gdf = pd.read_csv("/content/drive/MyDrive/NLP )0/project nlp mental health/counsel_chat_data.csv")
print(type(gdf))
# Load Kaggle dataset (assuming you've uploaded the .csv file)
kdf = pd.read_csv('/content/drive/MyDrive/NLP )0/project nlp mental health/counselchat-data.csv')
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
gdf.columns
# Out:
# Index(['questionID', 'questionTitle', 'questionText', 'questionLink', 'topic',
#        'therapistInfo', 'therapistURL', 'answerText', 'upvotes', 'views'],
#       dtype='object')

# %%
kdf.columns
# Out:
# Index(['questionID', 'questionTitle', 'questionText', 'questionUrl', 'topics',
#        'therapistName', 'therapistUrl', 'answerText', 'upvotes'],
#       dtype='object')

# %%
gdf.shape
# Out:
# (2775, 10)

# %%
kdf.shape
# Out:
# (1482, 9)

# %%
df1 = gdf.drop(['questionID', 'questionTitle', 'questionLink','therapistInfo', 'therapistURL', 'upvotes', 'views'], axis=1)
df2 = kdf.drop(['questionID', 'questionTitle', 'questionUrl','therapistName', 'therapistUrl', 'upvotes'], axis=1)
type(df1)
# Out:
# pandas.core.frame.DataFrame

# %%
df2.columns
# Out:
# Index(['questionText', 'topics', 'answerText'], dtype='object')

# %%
df2 = df2.rename(columns={'topics': 'topic'})
df2.columns
# Out:
# Index(['questionText', 'topic', 'answerText'], dtype='object')

# %%
# we do not need extra columns like therepist info, question url,upvotes', 'views so we will drop those and combine the data

# %%
# Combining 2 dfs
combined_df = pd.concat([df1, df2], ignore_index=True) # make sure both dfs have same structure

combined_df
# Out:
#                                            questionText  \
# 0     I have so many issues to address. I have a his...
# 1     I have so many issues to address. I have a his...
# 2     I have so many issues to address. I have a his...
# 3     I have so many issues to address. I have a his...
# 4     I have so many issues to address. I have a his...
# ...                                                 ...
# 4252  My grandson's step-mother sends him to school ...
# 4253  My boyfriend is in recovery from drug addictio...
# 4254  The birth mother attempted suicide several tim...
# 4255  I think adult life is making him depressed and...
# 4256  I just took a job that requires me to travel f...
#
#                                                  topic  \
# 0                                           depression
# 1                                           depression
# 2                                           depression
# 3                                           depression
# ...

# %%
print("df1 : ",df1.shape, "\ndf2 : ",df2.shape, "\ncombined_df : ",combined_df.shape)
# Out:
# df1 :  (2775, 3)
# df2 :  (1482, 3)
# combined_df :  (4257, 3)

# %%
# Dropping any null cell records
combined_df = combined_df.dropna()
combined_df.shape
# Out:
# (3988, 3)

# %%
# empthy data
empth = pd.read_csv("/content/drive/MyDrive/NLP )0/project nlp mental health/emotion-emotion_69k.csv")
empth.head()
# Out:
#    Unnamed: 0                                          Situation      emotion  \
# 0           0  I remember going to the fireworks with my best...  sentimental
# 1           1  I remember going to the fireworks with my best...  sentimental
# 2           2  I remember going to the fireworks with my best...  sentimental
# 3           3  I remember going to the fireworks with my best...  sentimental
# 4           4  I remember going to the fireworks with my best...  sentimental
#
#                                 empathetic_dialogues  \
# 0  Customer :I remember going to see the firework...
# 1  Customer :This was a best friend. I miss her.\...
# 2              Customer :We no longer talk.\nAgent :
# 3  Customer :Was this a friend you were in love w...
# 4             Customer :Where has she gone?\nAgent :
#
#                                               labels Unnamed: 5 Unnamed: 6
# 0  Was this a friend you were in love with, or ju...        NaN        NaN
# ...

# %%
empth.Situation[0]
# Out:
# 'I remember going to the fireworks with my best friend. There was a lot of people, but it only felt like us in the world.'

# %%
empth.empathetic_dialogues[0]
# Out:
# 'Customer :I remember going to see the fireworks with my best friend. It was the first time we ever spent time alone together. Although there was a lot of people, we felt like the only people in the world.\nAgent :'

# %%
empth.emotion.unique()
# Out:
# array(['sentimental', 'afraid', 'proud', 'faithful', 'terrified',
#        'joyful', 'angry', 'sad', 'jealous', 'grateful', 'prepared',
#        'embarrassed', 'excited', 'annoyed', 'lonely', 'ashamed', 'guilty',
#        'surprised', 'nostalgic', 'confident', 'furious', 'disappointed',
#        'caring', 'trusting', 'disgusted', 'anticipating', 'anxious',
#        'hopeful', 'content', 'impressed', 'apprehensive', 'devastated',
#        ' I really killed it!', ' we were in a different country',
#        't even like scary things',
#        't believe I like the show Power so much. I was never really into shows like that',
#        nan, ' time to jump on the motorcycle and go cruising!',
#        " a boy.  I hear all these different labor stories that aren't exactly reassuring!  ",
#        't believe my daughter taught herself how to play the ukelele. I was amazed',
#        't think I wold like super heroes',
# ...

# %%
empth.shape
# Out:
# (64636, 7)

# %%
import pandas as pd

# Example list of values to drop
values_to_drop = ['sentimental', 'afraid', 'proud', 'faithful', 'terrified',
       'joyful', 'angry', 'sad', 'jealous', 'grateful', 'prepared',
       'embarrassed', 'excited', 'annoyed', 'lonely', 'ashamed', 'guilty',
       'surprised', 'nostalgic', 'confident', 'furious', 'disappointed',
       'caring', 'trusting', 'disgusted', 'anticipating', 'anxious',
       'hopeful', 'content', 'impressed', 'apprehensive', 'devastated']

# Drop rows where 'xyz' is in the list
df0 = empth[empth['emotion'].isin(values_to_drop)]
df0
# Out:
#        Unnamed: 0                                          Situation  \
# 0               0  I remember going to the fireworks with my best...
# 1               1  I remember going to the fireworks with my best...
# 2               2  I remember going to the fireworks with my best...
# 3               3  I remember going to the fireworks with my best...
# 4               4  I remember going to the fireworks with my best...
# ...           ...                                                ...
# 64631       64631  I found some pictures of my grandma in the att...
# 64632       64632  I found some pictures of my grandma in the att...
# 64633       64633  I woke up this morning to my wife telling me s...
# 64634       64634  I woke up this morning to my wife telling me s...
# 64635       64635  I woke up this morning to my wife telling me s...
#
#            emotion                               empathetic_dialogues  \
# ...

# %%
df0.columns
# Out:
# Index(['Unnamed: 0', 'Situation', 'emotion', 'empathetic_dialogues', 'labels',
#        'Unnamed: 5', 'Unnamed: 6'],
#       dtype='object')

# %%
df0.emotion.unique()
# Out:
# array(['sentimental', 'afraid', 'proud', 'faithful', 'terrified',
#        'joyful', 'angry', 'sad', 'jealous', 'grateful', 'prepared',
#        'embarrassed', 'excited', 'annoyed', 'lonely', 'ashamed', 'guilty',
#        'surprised', 'nostalgic', 'confident', 'furious', 'disappointed',
#        'caring', 'trusting', 'disgusted', 'anticipating', 'anxious',
#        'hopeful', 'content', 'impressed', 'apprehensive', 'devastated'],
#       dtype=object)

# %%
df0 = df0.drop(['Unnamed: 0', 'Situation','Unnamed: 5', 'Unnamed: 6'], axis=1,)
df0
# Out:
#            emotion                               empathetic_dialogues  \
# 0      sentimental  Customer :I remember going to see the firework...
# 1      sentimental  Customer :This was a best friend. I miss her.\...
# 2      sentimental              Customer :We no longer talk.\nAgent :
# 3      sentimental  Customer :Was this a friend you were in love w...
# 4      sentimental             Customer :Where has she gone?\nAgent :
# ...            ...                                                ...
# 64631  sentimental    Customer :Did you find anything great?\nAgent :
# 64632  sentimental      Customer :What a wonderful memory.  \nAgent :
# 64633    surprised  Customer :I woke up this morning to my wife te...
# 64634    surprised  Customer :It is soooo awesome.  We have been w...
# 64635    surprised  Customer :Oh hey that's awesome!  That is awes...
#
#                                                   labels
# 0      Was this a friend you were in love with, or ju...
# ...

# %%
# Renaming hte columns to fit in the combined data
df0 = df0.rename(columns={'emotion': 'topic', 'empathetic_dialogues': 'questionText', 'labels':'answerText'})
df0
# Out:
#              topic                                       questionText  \
# 0      sentimental  Customer :I remember going to see the firework...
# 1      sentimental  Customer :This was a best friend. I miss her.\...
# 2      sentimental              Customer :We no longer talk.\nAgent :
# 3      sentimental  Customer :Was this a friend you were in love w...
# 4      sentimental             Customer :Where has she gone?\nAgent :
# ...            ...                                                ...
# 64631  sentimental    Customer :Did you find anything great?\nAgent :
# 64632  sentimental      Customer :What a wonderful memory.  \nAgent :
# 64633    surprised  Customer :I woke up this morning to my wife te...
# 64634    surprised  Customer :It is soooo awesome.  We have been w...
# 64635    surprised  Customer :Oh hey that's awesome!  That is awes...
#
#                                               answerText
# 0      Was this a friend you were in love with, or ju...
# ...

# %%
# rearranging the columns
df0 = df0[['questionText', 'topic', 'answerText']] # Rearrange columns
df0
# Out:
#                                             questionText        topic  \
# 0      Customer :I remember going to see the firework...  sentimental
# 1      Customer :This was a best friend. I miss her.\...  sentimental
# 2                  Customer :We no longer talk.\nAgent :  sentimental
# 3      Customer :Was this a friend you were in love w...  sentimental
# 4                 Customer :Where has she gone?\nAgent :  sentimental
# ...                                                  ...          ...
# 64631    Customer :Did you find anything great?\nAgent :  sentimental
# 64632      Customer :What a wonderful memory.  \nAgent :  sentimental
# 64633  Customer :I woke up this morning to my wife te...    surprised
# 64634  Customer :It is soooo awesome.  We have been w...    surprised
# 64635  Customer :Oh hey that's awesome!  That is awes...    surprised
#
#                                               answerText
# 0      Was this a friend you were in love with, or ju...
# ...

# %%
[df0.questionText[0:10]]
# Out:
# [0    Customer :I remember going to see the firework...
#  1    Customer :This was a best friend. I miss her.\...
#  2                Customer :We no longer talk.\nAgent :
#  3    Customer :Was this a friend you were in love w...
#  4               Customer :Where has she gone?\nAgent :
#  5    Customer : it feels like hitting to blank wall...
#  6    Customer :dont you feel so.. its a wonder \nAg...
#  7    Customer : i virtually thought so.. and i used...
#  8     Customer :Oh ya? I don't really see how\nAgent :
#  9    Customer :I do actually hit blank walls a lot ...
#  Name: questionText, dtype: object]

# %%
# Remove "costumer:" from the beginning of each value in the 'text' column
df0['questionText'] = df0['questionText'].str.replace(r'^Customer :\s*', '', regex=True)
df0.head()
# Out:
#                                         questionText        topic  \
# 0  I remember going to see the fireworks with my ...  sentimental
# 1       This was a best friend. I miss her.\nAgent :  sentimental
# 2                        We no longer talk.\nAgent :  sentimental
# 3  Was this a friend you were in love with, or ju...  sentimental
# 4                       Where has she gone?\nAgent :  sentimental
#
#                                           answerText
# 0  Was this a friend you were in love with, or ju...
# 1                                Where has she gone?
# 2  Oh was this something that happened because of...
# 3                This was a best friend. I miss her.
# 4                                 We no longer talk.

# %%
df0 = df0.dropna()
df0.shape
# Out:
# (64591, 3)

# %%
# Time to comn=bine this with df1 and df2
# df0 : empathetic facebook data
# df1 : github data
# df2 : kaggle data

# %%
combined_df.shape
# Out:
# (3988, 3)

# %%
combined_df = pd.concat([combined_df, df0], ignore_index=True) # make sure both dfs have same structure
combined_df.shape
# Out:
# (68579, 3)

# %%
# will save clean data for training in .csv file
combined_df.to_csv('data.csv', index=False)
